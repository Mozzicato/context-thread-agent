# %%
print(f'Original shape: {df.shape}')
df.head()

# %%
# Remove incomplete Q4 data
df = df[df['quarter'] != 'Q4']
print(f'Q4 rows removed: {12000 - len(df)}')

# %% [markdown]
# ## Data Cleaning Complete
#
# We've removed Q4 data which contains incomplete records.

# %%
# Group by month and calculate revenue
monthly_revenue = df.groupby('month')['revenue'].sum()
monthly_revenue

# %%
# Visualize the trend
import matplotlib.pyplot as plt
monthly_revenue.plot(figsize=(12, 6), title='Monthly Revenue Trend')
plt.show()
